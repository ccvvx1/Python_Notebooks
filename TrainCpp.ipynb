# %%
# !git clone https://github.com/ccvvx1/Python_CppExample.git
# %cd Python_CppExample

# %%
# !pip install ninja
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --extra-index-url https://download.pytorch.org/whl/cu118

# %%
# %cd /content/Python_CppExample/freqencoder/src/lua547
# !make

# %%
# !git pull

# %%
# %cd /content/Python_CppExample

# %%
# %cd /content/tmp2

# %%
# !ninja -v

# %%
import os
os.environ['TORCH_CUDA_ARCH_LIST'] = ''

# %%
# !mkdir /content/tmp2

# %%
from freqencoder import FreqEncoder
encoder = FreqEncoder(input_dim=1, degree=2)

# %%
ret = encoder.print_info("detail")
print("ret: ", ret)

# %% [markdown]
# ## 0 创建环境

# %%
# !git clone https://github.com/ccvvx1/Python_Env.git
# %cd Python_Env
# !bash setupEnv.sh
# %cd /content

# %%
# !curl -Lo /usr/bin/cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 && chmod +x /usr/bin/cloudflared
# !echo IyEvYmluL2Jhc2gKCmN1cmwgLWZzU0wgaHR0cHM6Ly9jb2RlLXNlcnZlci5kZXYvaW5zdGFsbC5zaCB8IHNoCgpjb2RlLXNlcnZlciAgLS1hdXRoIG5vbmUgLS1iaW5kLWFkZHIgMC4wLjAuMDo5MDkw | base64 -d > /content/ok.sh

# %%
bash /content/ok.sh

# %%
# !git clone https://ccvvx1:ghp_1qQrwkaHSPedC2SWnaxF8K63rUeoVa063D7@github.com/ccvvx1/Python_Qwen2.git

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
# 启动后台任务并忽略挂断信号
# !nohup cloudflared tunnel --url localhost:9090 > cloudflared.log 2>&1 &

# 验证进程状态
# !ps aux | grep cloudflared

# %%
# !nohup http-server -p 9091 > http.log 2>&1 &
# !cloudflared tunnel --url localhost:9091

# %% [markdown]
# ## 1 调试qwen2

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig

model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.bfloat16, device_map="auto")
model.generation_config = GenerationConfig.from_pretrained(model_name)
model.generation_config.pad_token_id = model.generation_config.eos_token_id

text = "An attention function can be described as mapping a query and a set of key-value pairs to an output, where the query, keys, values, and output are all vectors. The output is"
inputs = tokenizer(text, return_tensors="pt")
model.save_pretrained("./depseek-ai")
# outputs = model.generate(**inputs.to(model.device), max_new_tokens=100)

# result = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(result)

# %%
# !git clone https://github.com/ccvvx1/Python_Qwen2.git

# %%
# !cp /content/depseek-ai/model.safetensors /content/Python_Qwen2/

# %%
# model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained("./Python_Qwen2", torch_dtype=torch.bfloat16, device_map="auto", trust_remote_code=True)

# %%
model

# %%
# %cd /content/Python_Qwen2
# !git pull
# %cd ..

# %% [markdown]
# ### 1.1 训练

# %%
# !pip install -q torch transformers datasets accelerate bitsandbytes --no-build-isolation trl

# %% [markdown]
# ## 2 调试窗口xterm

# %%
# !pip install colab-xterm
# %load_ext colabxterm

# %%
# !bash /content/Python_Qwen2/cmds/startCodeServer.js

# %%
# curl -fsSL https://code-server.dev/install.sh | sh

# %%
# !curl -Lo /usr/bin/cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 && chmod +x /usr/bin/cloudflared

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
from IPython.display import HTML

# 嵌入本地视频
HTML("""
<video width="640" height="480" controls>
  <source src="/content/drive/MyDrive/Step Sis 说服 Virgin Gamer Step Bro 操她 - HORNY HOSTEL .mp4" type="video/mp4">
</video>
""")

# 嵌入在线视频（如YouTube）
# HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/XXXXX" frameborder="0" allowfullscreen></iframe>')

# %%
# !unzip /content/drive/MyDrive/Thunder——mw_repacked.zip

# %%
# !unzip -P your_password encrypted_file.zip

# %%
# !nohup http-server -p 9091 > http.log 2>&1 &
# !cloudflared tunnel --url localhost:9091

# %%
# 启动后台任务并忽略挂断信号
# !nohup cloudflared tunnel --url localhost:9090 > cloudflared.log 2>&1 &

# 验证进程状态
# !ps aux | grep cloudflared

# %%
# !cat /root/.config/code-server/config.yaml

# %%
# code-server --bind-addr 0.0.0.0:9090

# %xterm

# %% [markdown]
# ## 3 浏览器google chrome

# %%
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !sudo dpkg -i google-chrome-stable_current_amd64.deb
# !google-chrome --version  # 验证安装

# %%
# !apt --fix-broken install

# %%
# !google-chrome --no-sandbox --headless

# %% [markdown]
# ### 3.1 通过插件显示网页

# %%
from IPython import display

display.IFrame(src="https://www.baidu.com", width=1600, height=800)

# %%
from IPython.display import IFrame, HTML, display
import uuid

# 生成唯一 ID 标识 iframe
iframe_id = "my-iframe-" + str(uuid.uuid4())

# 嵌入百度页面
iframe = IFrame(src="https://www.baidu.com", width=1600, height=800)
display(iframe)

# 注入 JavaScript 尝试修改链接行为
display(HTML(f"""
<script>
  (function() {{
    const iframe = document.getElementById('{iframe_id}');

    // 监听 iframe 加载完成
    iframe.onload = function() {{
      try {{
        // 获取 iframe 内部文档（跨域时会失败）
        const iframeDoc = iframe.contentDocument || iframe.contentWindow.document;

        // 修改所有 target="_blank" 的链接
        const links = iframeDoc.querySelectorAll('a[target="_blank"]');
        links.forEach(link => {{
          link.target = "_self"; // 强制在当前 iframe 跳转
        }});
      }} catch (error) {{
        console.error('跨域限制，无法修改 iframe 内容:', error);
      }}
    }};
  }})();
</script>
"""))

# %%
from flask import Flask, Response
import requests

app = Flask(__name__)

@app.route('/proxy/baidu')
def proxy_baidu():
    response = requests.get('https://www.baidu.com')
    modified_html = response.text.replace('target="_blank"', 'target="_self"')
    return Response(modified_html, mimetype='text/html')

if __name__ == '__main__':
    app.run(port=5000)

# %%
from IPython.display import IFrame
IFrame(src="http://localhost:5000/proxy/baidu", width=1600, height=800)

# %% [markdown]
# ### 3.2 使用浏览器

# %%
# !apt install firefox

# %%
# !pip install selenium

# %%
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions

# %%
def selenium_firefox_agent(driver_path="geckodriver"):
    firefox_driver_path = f'{driver_path}'
    user_agent = 'Mozilla'
    firefox_options = FirefoxOptions()
    firefox_options.add_argument('--headless')
    firefox_options.set_preference("general.useragent.override", user_agent)

    driver = webdriver.Firefox(
        # executable_path=firefox_driver_path,
        options=firefox_options
    )
    print('Scraper setup complete!')
    return driver

# %%
crawler = selenium_firefox_agent()
crawler.get("https://www.baidu.com/")
source = crawler.page_source
print(crawler.title)
crawler.save_screenshot("google.png")  # 保存为图片

# %% [markdown]
# ## 4 模型训练

# %%
# !pip install -q torch transformers datasets accelerate bitsandbytes --no-build-isolation

# %%
# !pip install trl

# %% [markdown]
# ## 5 调试rust

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y

# %%
# !cargo new prj
# %cd prj
# !cargo run

# %% [markdown]
# ## 6 调试go

# %%
# 下载Go 1.21.6稳定版（截至2025年最新LTS版本）
# !wget https://go.dev/dl/go1.21.6.linux-amd64.tar.gz

# 解压到系统目录
# !tar -C /usr/local -xzf go1.21.6.linux-amd64.tar.gz
# !echo export PATH=$PATH::/usr/local/go/bin >> ~/.bashrc
# !go env -w GO111MODULE=auto
# !go mod tidy
# 配置环境变量
import os
os.environ['PATH'] += ":/usr/local/go/bin"
os.environ['GOPATH'] = "/content/go"
os.environ['GOROOT'] = "/usr/local/go"

# !git clone https://github.com/ccvvx1/Go_pion.git
# !go install -v golang.org/x/tools/gopls@v0.9.5
# !go get github.com/pion/webrtc
# !mkdir /root/go/src/github.com/pion/webrtc /root/go/src/github.com/pion/webrtc/v4
# !mv /root/go/src/github.com/pion/webrtc/* /root/go/src/github.com/pion/webrtc/v4
# !mkdir /root/go/src/github.com/pion/sdp /root/go/src/github.com/pion/sdp/v3
# !mv /root/go/src/github.com/pion/sdp/* /root/go/src/github.com/pion/sdp/v3
# !mkdir /root/go/src/github.com/pion/srtp /root/go/src/github.com/pion/srtp/v3
# !mv /root/go/src/github.com/pion/srtp/* /root/go/src/github.com/pion/srtp/v3
# !mkdir /root/go/src/github.com/pion/ice /root/go/src/github.com/pion/ice/v4
# !mv /root/go/src/github.com/pion/ice/* /root/go/src/github.com/pion/ice/v4

# %% [markdown]
# ## 7 调试ffmpeg代码

# %%
# !git clone https://github.com/FFmpeg/FFmpeg.git

# %%
# %cd FFmpeg
# !wget https://img2.woyaogexing.com/2019/02/08/1feeabfeb4c54028adbabcb575586d7e!400x400.jpeg -o 1.jpg
# !./configure  --disable-x86asm

# %%
# !./make

# %% [markdown]
# ## 8 调试electron

# %%
# !git clone https://github.com/electron/electron-quick-start
# %cd electron-quick-start
# !npm i
# 需要在运行脚本添加--no-sandbox
# 需要设置显示器export DISPLAY=:55
# !npm start

# %% [markdown]
# ## 9 调试stable diffusion web

# %%
# !apt install python3.10-venv

# %%
# !git clone https://github.com/ccvvx1/Python_sd_web.git
